# %%
import numpy as np
import matplotlib.pyplot as plt
import skimage.io as io

# %%
img=io.imread('/kaggle/input/pictur/umer.jpeg')

# %%
plt.imshow(img)
plt.show()

# %%
img.shape
# Out:
# (960, 960, 3)

# %%
red=img[:,:,0]
green=img[:,:,1]
blue=img[:,:,2]

# %%
plt.imshow(red,cmap='Reds')
plt.show()

# %%
plt.imshow(green,cmap='Greens')
plt.show()

# %%
plt.imshow(blue,cmap='Blues')
plt.show()

# %%
pip install Pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from PIL import Image
img2=Image.open('/kaggle/input/pictur/umer.jpeg').convert('L')
img2.save('grayumer.jpeg')

# %%
img2=io.imread('/kaggle/working/grayumer.jpeg')
plt.imshow(img2,cmap='Greys_r')
plt.show()

# %%
img2.shape
# Out:
# (960, 960)

# %% [markdown]
# # Affine Transformation

# %%
import tensorflow as tf
transformati=tf.keras.preprocessing.image.apply_affine_transform(img,zx=.15,zy=.1)
plt.imshow(transformati)
plt.show()
